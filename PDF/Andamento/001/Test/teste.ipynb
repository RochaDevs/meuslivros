# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
len?
# Out:
# Signature: len(obj, /)
# Docstring: Return the number of items in a container.
# Type:      builtin_function_or_method

# %%
l = [1, 2, 3]

# %%
l.insert?
# Out:
# Signature: l.insert(index, object, /)
# Docstring: Insert object before index.
# Type:      builtin_function_or_method

# %%
def square(a):
    """Return the square of a"""
    return a ** 2

# %%
square?
# Out:
# Signature: square(a)
# Docstring: Return the square of a
# File:      c:\users\matheus.revangelista\appdata\local\temp\ipykernel_37804\2037369859.py
# Type:      function

# %%
square??
# Out:
# Signature: square(a)
# Source:
# def square(a):
#     """Return the square of a"""
#     return a ** 2
# File:      c:\users\matheus.revangelista\appdata\local\temp\ipykernel_37804\2037369859.py
# Type:      function

# %%
*Warning?
# Out:
# BytesWarning
# DeprecationWarning
# EncodingWarning
# FutureWarning
# ImportWarning
# PendingDeprecationWarning
# ResourceWarning
# RuntimeWarning
# SyntaxWarning
# UnicodeWarning
# UserWarning
# Warning

# %%
str.*find*?
# Out:
# str.find
# str.rfind
