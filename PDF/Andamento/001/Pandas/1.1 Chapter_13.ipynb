# %%
""" 
    Introducing Pandas Objects

        At a very basic level, Pandas objects can be thought of as enhanced versions of NumPy structured arrays in which the rows and columns are identified with labels 
        rather than simple integer indices.

        The Pandas Series Object

            A Pandas Series is a one-dimensional array of indexed data. It can be created from a list or arrays as follows:
"""
# Out:
# ' \n    Introducing Pandas Objects\n\n        At a very basic level, Pandas objects can be thought of as enhanced versions of NumPy structured arrays in which the rows and columns are identified with labels \n        rather than simple integer indices.\n\n        The Pandas Series Object\n\n            A Pandas Series is a one-dimensional array of indexed data. It can be created from a list or arrays as follows:\n'

# %%
import numpy as np
import pandas as pd

# %%
data = pd.Series([0.25, 0.5, 0.75, 1.0])
data
# Out:
# 0    0.25
# 1    0.50
# 2    0.75
# 3    1.00
# dtype: float64

# %%
"""
    The Series combines a sequencie of values with a explicit sequence of indices, which we can access with the 'values' and 'index' attributes. The values are simply a familiar NumPy array:
"""
# Out:
# '\n    The Series combines a sequencie of values with a explicit sequence of indices, which we can access with the values and index attributes. The values are simply a familiar NumPy array:\n'

# %%
data.values
# Out:
# array([0.25, 0.5 , 0.75, 1.  ])

# %%
data.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
data[1]
# Out:
# np.float64(0.5)

# %%
data[1:3]
# Out:
# 1    0.50
# 2    0.75
# dtype: float64

# %%
"""
    Series as Generalizes Numpy Array

        From what we've seen so far, the Series object may appear to be basically interchangeable with a one-dimensional NumPy array. The essencial difference is that while the NumPy 
        array has an 'implicitly defined' integer index uses to access the values, the Pandas Series has an 'explicitly defined' index associated with the values.

        The explicit index definition gives the Series object additional capabilities. For example, the index need not be an integer, but can consist of values of any desired type. So,
        if we wish, we can use strings as an index:
"""
# Out:
# "\n    Series as Generalizes Numpy Array\n\n        From what we've seen so far, the Series object may appear to be basically interchangeable with a one-dimensional NumPy array. The essencial difference is that while the NumPy \n        array has an 'implicitly defined' integer index uses to access the values, the Pandas Series has an 'explicitly defined' index associated with the values.\n\n        The explicit index definition gives the Series object additional capabilities. For example, the index need not be an integer, but can consist of values of any desired type. So,\n        if we wish, we can use strings as an index:\n"

# %%
data = pd.Series([25, 24, 6, 1], index=['Matheus', 'Sara', 'Liz', 'Catarina'])
data
# Out:
# Matheus     25
# Sara        24
# Liz          6
# Catarina     1
# dtype: int64

# %%
data['Catarina']
# Out:
# np.int64(1)

# %%
data1 = pd.Series([10, 20, 30, 40], index=[2, 6, 0, 1])
data1
# Out:
# 2    10
# 6    20
# 0    30
# 1    40
# dtype: int64

# %%
"""
    Series as Specialized Dictionary

        In this way, you can think of a Pandas Series a bit like a specialization of a Python dictionary. A dictionary is a structure that maps arbitrary keys to a set of arbitrary values,
        and a Series is a structure that maps typed keys to a set of typed values. This typing is important: just as the type-specific compiled code behind a Numpy array makes it more efficient
        than a Python list of certain operations, the type information or a Pandas Series makes it more efficient than Python dictionaries for a certain operations.
"""
# Out:
# '\n    Series as Specialized Dictionary\n\n        In this way, you can think of a Pandas Series a bit like a specialization of a Python dictionary. A dictionary is a structure that maps arbitrary keys to a set of arbitrary values,\n        and a Series is a structure that maps typed keys to a set of typed values. This typing is important: just as the type-specific compiled code behind a Numpy array makes it more efficient\n        than a Python list of certain operations, the type information or a Pandas Series makes it more efficient than Python dictionaries for a certain operations.\n'

# %%
family_members_dict = {
    'Matheus': 4,
    'Edilson': 3,
    'Adriano': 4,
    'Janpiere': 2,
    'Alecio': 3
}
family_members = pd.Series(family_members_dict)
family_members
# Out:
# Matheus     4
# Edilson     3
# Adriano     4
# Janpiere    2
# Alecio      3
# dtype: int64

# %%
family_members['Matheus']
# Out:
# np.int64(4)

# %%
family_members['Matheus':'Adriano']
# Out:
# Matheus    4
# Edilson    3
# Adriano    4
# dtype: int64
